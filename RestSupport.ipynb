# %%
import numpy as np
import pandas as pd
data = pd.read_csv("train.csv")
print(data)
# Out:
#       Id   Open Date        City  City Group  ... P35  P36  P37    revenue
# 0      0  07/17/1999    İstanbul  Big Cities  ...   4    3    4  5653753.0
# 1      1  02/14/2008      Ankara  Big Cities  ...   0    0    0  6923131.0
# 2      2  03/09/2013  Diyarbakır       Other  ...   0    0    0  2055379.0
# 3      3  02/02/2012       Tokat       Other  ...  12   12    6  2675511.0
# 4      4  05/09/2009   Gaziantep       Other  ...   4    3    3  4316715.0
# ..   ...         ...         ...         ...  ...  ..  ...  ...        ...
# 132  132  06/25/2008     Trabzon       Other  ...   0    0    0  5787594.0
# 133  133  10/12/2006       İzmir  Big Cities  ...   0    0    0  9262754.0
# 134  134  07/08/2006     Kayseri       Other  ...   0    0    0  2544857.0
# 135  135  10/29/2010    İstanbul  Big Cities  ...   0    0    0  7217634.0
# 136  136  09/01/2009    İstanbul  Big Cities  ...   0    0    0  6363241.0
#
# [137 rows x 43 columns]

# %%
data = data.drop(columns=['Open Date', 'City','City Group', 'Type'])

# %%
data.head()
# Out:
#    Id  P1   P2   P3   P4  P5  P6  ...  P32  P33  P34  P35  P36  P37    revenue
# 0   0   4  5.0  4.0  4.0   2   2  ...    4    5    5    4    3    4  5653753.0
# 1   1   4  5.0  4.0  4.0   1   2  ...    0    0    0    0    0    0  6923131.0
# 2   2   2  4.0  2.0  5.0   2   3  ...    0    0    0    0    0    0  2055379.0
# 3   3   6  4.5  6.0  6.0   4   4  ...   10    6   18   12   12    6  2675511.0
# 4   4   3  4.0  3.0  4.0   2   2  ...    3    2    3    4    3    3  4316715.0
#
# [5 rows x 39 columns]

# %%
from sklearn.model_selection import train_test_split

X=data.drop('revenue', axis=1)  
y=data.revenue  

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)


from sklearn.ensemble import RandomForestRegressor

classifier = RandomForestRegressor(n_estimators = 1000)

classifier.fit(X_train, y_train);

# %%
y_pred = classifier.predict(X_train)
import sklearn.metrics as metrics
z = float(metrics.mean_squared_error(y_train, y_pred))
print(z)
# Out:
# 0.53

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# Load the diabetes dataset
X_train, y_train = datasets.load_diabetes(return_X_y=True)

# Use only one feature
X_train = X_train[:, np.newaxis, 2]

# Split the data into training/testing sets
X_train = X_train[:-20]
X_test = X_train[-20:]

# Split the targets into training/testing sets
y_train = y_train[:-20]
y_test = y_train[-20:]

# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(X_train, y_train)

# Make predictions using the testing set
diabetes_y_pred = regr.predict(X_train)

# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error


# Plot outputs
plt.scatter(X_test, y_test,  color='black')
plt.plot(X_test, y_test, color='blue', linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()
# Out:
# Coefficients:
#  [938.23786125]

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
import pickle
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
 
y = data['revenue']
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2)
classifier = RandomForestClassifier(n_estimators = 50, criterion = 'entropy', random_state = 0)
classifier.fit(X_train, y_train)
pred = classifier.predict(X_test)

accuracy = accuracy_score(y_test, pred)
print("accuracy: " + str(accuracy * 100) + "%")
# Out:
# accuracy: 72.0%

# %%
import numpy as np
import pandas as pd
data = pd.read_csv("train.csv")
print(data)
# Out:
#       Id   Open Date        City  City Group  ... P35  P36  P37    revenue
# 0      0  07/17/1999    İstanbul  Big Cities  ...   4    3    4  5653753.0
# 1      1  02/14/2008      Ankara  Big Cities  ...   0    0    0  6923131.0
# 2      2  03/09/2013  Diyarbakır       Other  ...   0    0    0  2055379.0
# 3      3  02/02/2012       Tokat       Other  ...  12   12    6  2675511.0
# 4      4  05/09/2009   Gaziantep       Other  ...   4    3    3  4316715.0
# ..   ...         ...         ...         ...  ...  ..  ...  ...        ...
# 132  132  06/25/2008     Trabzon       Other  ...   0    0    0  5787594.0
# 133  133  10/12/2006       İzmir  Big Cities  ...   0    0    0  9262754.0
# 134  134  07/08/2006     Kayseri       Other  ...   0    0    0  2544857.0
# 135  135  10/29/2010    İstanbul  Big Cities  ...   0    0    0  7217634.0
# 136  136  09/01/2009    İstanbul  Big Cities  ...   0    0    0  6363241.0
#
# [137 rows x 43 columns]

# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn import linear_model
from sklearn.utils import shuffle

data = pd.read_csv("train.csv")

data = data.drop(columns=['Open Date', 'City','City Group', 'Type'])

predict = "revenue"

X = np.array(data.drop([predict], 1))
y = np.array(data[predict])

x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, test_size = 0.1)

linear = linear_model.LinearRegression()

linear.fit(x_train, y_train)
acc = linear.score(x_test, y_test)
print(acc)

print('Coefficient: \n', linear.coef_)
print('Intercept: \n', linear.intercept_)

predictions = linear.predict(x_test)

for x in range(len(predictions)):
    print(predictions[x], x_test[x], y_test[x])
# Out:
# -2.878380709009942
# Coefficient:
#  [    5035.72750419   488605.50122552   185133.77600619   -31812.99230637
#   -369501.30546607   -53621.27642265   552468.38236306   -47817.98508274
#  -1453206.099051    1240068.49399305   367979.97526625  -174209.59703527
#     19916.58296958 -1256875.92345724  -250681.34929931    49820.65885524
#  -1086201.26459152   549634.35427196  1223536.26858121   -59341.31960537
#   -367333.00802987   246742.1158911   -204154.44839818    24356.56289249
#    790251.63250561   189159.12122079 -1400628.55476721    50174.88353568
#    399140.56084575  -214915.08322511   330833.65852312   266663.92536143
#   -635805.02600088  -646068.90005323   275434.51700971  -568613.51711012
#    408318.97779765   506803.88097189]
# Intercept:
#  8523279.589538936
# 6021668.263126012 [44.  2.  3.  5.  3.  1.  5.  5.  5.  5.  5.  1.  5.  5.  1.  1.  3.  1.
#   4.  1.  3.  1.  2.  1.  1.  1.  1.  1.  2.  3.  3.  5.  5.  2.  3.  4.
#   3.  4.] 4264176.0
# 8742084.014853304 [112.   4.   5.   5.   4.   1.   5.   5.   5.   4.   4.   2.   4.   4.
#    3.   4.   2.   1.   4.   2.   3.   2.   2.   1.   3.   3.   4.   5.
#    3.   3.   3.   2.   1.   2.   2.   1.   3.   3.] 3784230.0
# 6116670.974734919 [73.  4.  5.  4.  5.  2.  2.  5.  3.  4.  5.  5.  4.  5.  0.  0.  0.  0.
#   0.  5.  5.  5.  5.  5.  0.  0.  0.  0.  5.  0.  0.  0.  0.  0.  0.  0.
#   0.  0